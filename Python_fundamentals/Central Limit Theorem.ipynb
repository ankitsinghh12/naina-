# %%
import warnings
warnings.filterwarnings("ignore")

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import random
random.seed = 42

# %%
df=pd.read_csv("adult.csv")

# %%
df.head()
# Out:
#    age         workclass  fnlwgt  education  education-num  \
# 0    2         State-gov   77516  Bachelors             13
# 1    3  Self-emp-not-inc   83311  Bachelors             13
# 2    2           Private  215646    HS-grad              9
# 3    3           Private  234721       11th              7
# 4    1           Private  338409  Bachelors             13
#
#        marital-status         occupation   relationship   race     sex  \
# 0       Never-married       Adm-clerical  Not-in-family  White    Male
# 1  Married-civ-spouse    Exec-managerial        Husband  White    Male
# 2            Divorced  Handlers-cleaners  Not-in-family  White    Male
# 3  Married-civ-spouse  Handlers-cleaners        Husband  Black    Male
# 4  Married-civ-spouse     Prof-specialty           Wife  Black  Female
#
#    capitalgain  capitalloss  hoursperweek native-country  class
# 0            1            0             2  United-States  <=50K
# 1            0            0             0  United-States  <=50K
# 2            0            0             2  United-States  <=50K
# 3            0            0             2  United-States  <=50K
# 4            0            0             2           Cuba  <=50K

# %%
df.shape
# Out:
# (48842, 15)

# %%
df.describe()
# Out:
#                 age        fnlwgt  education-num   capitalgain   capitalloss  \
# count  48842.000000  4.884200e+04   48842.000000  48842.000000  48842.000000
# mean       1.771078  1.896641e+05      10.078089      0.200319      0.114942
# std        1.295378  1.056040e+05       2.570973      0.746182      0.556924
# min        0.000000  1.228500e+04       1.000000      0.000000      0.000000
# 25%        1.000000  1.175505e+05       9.000000      0.000000      0.000000
# 50%        2.000000  1.781445e+05      10.000000      0.000000      0.000000
# 75%        3.000000  2.376420e+05      12.000000      0.000000      0.000000
# max        4.000000  1.490400e+06      16.000000      4.000000      4.000000
#
#        hoursperweek
# count  48842.000000
# mean       1.950698
# std        0.897038
# min        0.000000
# 25%        2.000000
# 50%        2.000000
# 75%        2.000000
# max        4.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48842 entries, 0 to 48841
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             48842 non-null  int64
#  1   workclass       46043 non-null  object
#  2   fnlwgt          48842 non-null  int64
#  3   education       48842 non-null  object
#  4   education-num   48842 non-null  int64
#  5   marital-status  48842 non-null  object
#  6   occupation      46033 non-null  object
#  7   relationship    48842 non-null  object
#  8   race            48842 non-null  object
#  9   sex             48842 non-null  object
#  10  capitalgain     48842 non-null  int64
#  11  capitalloss     48842 non-null  int64
#  12  hoursperweek    48842 non-null  int64
#  13  native-country  47985 non-null  object
#  14  class           48842 non-null  object
# dtypes: int64(6), object(9)
# memory usage: 5.6+ MB

# %%
sns.distplot(df['age'])
# Out:
# <AxesSubplot:xlabel='age', ylabel='Density'>

# %%
print('Number of rows: ', df.shape[0])
# Out:
# Number of rows:  48842

# %%
samples = random.sample(range(0, df.shape[0]), 50)                    #creating a sample of 50 random values

# %%
df.iloc[samples]
# Out:
#        age         workclass  fnlwgt     education  education-num  \
# 27981    0           Private  184543     Assoc-voc             11
# 43004    0           Private  375079  Some-college             10
# 20624    1           Private  169672          11th              7
# 24448    0           Private  239098       HS-grad              9
# 45961    1           Private  206889       HS-grad              9
# 41481    2           Private  345310  Some-college             10
# 6390     2  Self-emp-not-inc  315406          11th              7
# 1225     1           Private  236436       HS-grad              9
# 35927    1           Private  103651     Bachelors             13
# 5261     1           Private  376936       HS-grad              9
# 39820    1           Private  373545       HS-grad              9
# 38567    1         Local-gov  230997     Bachelors             13
# 25628    3      Self-emp-inc  188067  Some-college             10
# 34121    3               NaN  125659       HS-grad              9
# 43908    2           Private  173981       HS-grad              9
# 48823    3           Private   82720       HS-grad              9
# 28229    2           Private  193815    Assoc-acdm             12
# 43575    1           Private  130007          10th              6
# 13997    3           Private   25468       Masters             14
# 43553    4           Private  278515       HS-grad              9
# 44937    0           Private  348867       HS-grad              9
# 24674    0           Private  113099       HS-grad              9
# 5740     1           Private  273818  Some-college             10
# 25570    1           Private  148429       HS-grad              9
# 8978     4           Private  296485       5th-6th              3
# 25406    1           Private  122206       HS-grad              9
# 28765    4           Private  156310          10th              6
# 18544    3           Private  186272       HS-grad              9
# 33959    4      Self-emp-inc  220667       7th-8th              4
# 5241     3           Private  207367  Some-college             10
# 4828     1           Private  193650          11th              7
# 34198    0           Private  187447  Some-college             10
# 36147    3  Self-emp-not-inc  139023  Some-college             10
# 2689     0               NaN  216563       HS-grad              9
# 22895    4           Private   68539  Some-college             10
# 25728    4           Private  177791          10th              6
# 22787    3       Federal-gov   31965  Some-college             10
# 36511    2      Self-emp-inc  149102     Assoc-voc             11
# 44088    1           Private   53271       HS-grad              9
# 23586    2           Private  168283       HS-grad              9
# 1151     2           Private  520586  Some-college             10
# 1066     1           Private  199352   Prof-school             15
# 21880    0           Private  163665     Bachelors             13
# 39424    0           Private  189663       Masters             14
# 1881     2           Private  102606     Bachelors             13
# 40415    2  Self-emp-not-inc   45136   Prof-school             15
# 48318    3           Private  261207       HS-grad              9
# 4432     2  Self-emp-not-inc  230478    Assoc-acdm             12
# 47826    0           Private  133712       HS-grad              9
# 48404    3           Private  158944       HS-grad              9
#
#               marital-status         occupation    relationship   race  \
# 27981          Never-married       Adm-clerical   Not-in-family  White
# 43004          Never-married      Other-service       Own-child  White
# 20624     Married-civ-spouse              Sales         Husband  White
# 24448          Never-married      Other-service       Unmarried  White
# 45961          Never-married  Handlers-cleaners   Not-in-family  White
# 41481               Divorced      Other-service       Unmarried  White
# 6390      Married-civ-spouse    Farming-fishing         Husband  White
# 1225           Never-married       Adm-clerical   Not-in-family  White
# 35927     Married-civ-spouse    Exec-managerial         Husband  White
# 5261           Never-married       Craft-repair   Not-in-family  White
# 39820          Never-married  Handlers-cleaners   Not-in-family  White
# 38567          Never-married     Prof-specialty   Not-in-family  White
# 25628                Widowed              Sales       Unmarried  White
# 34121     Married-civ-spouse                NaN            Wife  White
# 43908     Married-civ-spouse      Other-service         Husband  White
# 48823     Married-civ-spouse       Craft-repair         Husband  White
# 28229     Married-civ-spouse     Prof-specialty         Husband  White
# 43575               Divorced              Sales       Own-child  White
# 13997               Divorced    Exec-managerial   Not-in-family  White
# 43553               Divorced       Adm-clerical       Unmarried  Black
# 44937          Never-married              Sales  Other-relative  Black
# 24674              Separated       Craft-repair   Not-in-family  Black
# 5740      Married-civ-spouse      Other-service         Husband  White
# 25570     Married-civ-spouse  Machine-op-inspct         Husband  White
# 8978      Married-civ-spouse   Transport-moving         Husband  White
# 25406          Never-married       Craft-repair  Other-relative  White
# 28765     Married-civ-spouse      Other-service         Husband  White
# 18544               Divorced              Sales   Not-in-family  White
# 33959                Widowed    Exec-managerial   Not-in-family  White
# 5241   Married-spouse-absent      Other-service   Not-in-family  White
# 4828                Divorced      Other-service   Not-in-family  White
# 34198              Separated      Other-service       Own-child  White
# 36147     Married-civ-spouse              Sales         Husband  White
# 2689           Never-married                NaN  Other-relative  White
# 22895               Divorced       Adm-clerical       Unmarried  White
# 25728               Divorced      Other-service       Own-child  White
# 22787     Married-civ-spouse       Adm-clerical         Husband  White
# 36511          Never-married       Craft-repair       Own-child  White
# 44088          Never-married   Transport-moving  Other-relative  White
# 23586     Married-civ-spouse      Other-service         Husband  White
# 1151                Divorced       Adm-clerical       Unmarried  White
# 1066      Married-civ-spouse     Prof-specialty         Husband  White
# 21880          Never-married      Other-service       Own-child  White
# 39424          Never-married     Prof-specialty       Own-child  White
# 1881      Married-civ-spouse       Tech-support         Husband  White
# 40415     Married-civ-spouse     Prof-specialty         Husband  White
# 48318     Married-civ-spouse      Other-service         Husband  White
# 4432                Divorced    Exec-managerial   Not-in-family  White
# 47826          Never-married      Other-service  Other-relative  White
# 48404                Widowed       Craft-repair   Not-in-family  White
#
#           sex  capitalgain  capitalloss  hoursperweek native-country  class
# 27981  Female            0            0             2  United-States  <=50K
# 43004    Male            0            0             1  United-States  <=50K
# 20624    Male            0            0             4  United-States  <=50K
# 24448  Female            0            0             2  United-States  <=50K
# 45961    Male            0            0             2  United-States  <=50K
# 41481  Female            0            0             1  United-States  <=50K
# 6390     Male            0            0             4  United-States  <=50K
# 1225   Female            0            0             2  United-States  <=50K
# 35927    Male            0            0             2  United-States   >50K
# 5261     Male            0            0             2  United-States  <=50K
# 39820    Male            0            0             2  United-States  <=50K
# 38567  Female            0            0             2  United-States  <=50K
# 25628  Female            0            0             2  United-States  <=50K
# 34121  Female            0            0             0  United-States   >50K
# 43908    Male            0            0             2            NaN  <=50K
# 48823    Male            0            0             2  United-States  <=50K
# 28229    Male            0            0             2  United-States   >50K
# 43575  Female            0            0             1  United-States  <=50K
# 13997    Male            4            0             3  United-States   >50K
# 43553  Female            0            0             2  United-States  <=50K
# 44937  Female            0            0             0  United-States  <=50K
# 24674    Male            0            0             2  United-States  <=50K
# 5740     Male            0            0             3         Mexico  <=50K
# 25570    Male            1            0             2  United-States  <=50K
# 8978     Male            0            0             2  United-States  <=50K
# 25406    Male            0            0             2  United-States  <=50K
# 28765    Male            1            0             0  United-States  <=50K
# 18544    Male            0            0             2  United-States  <=50K
# 33959  Female            0            0             2  United-States  <=50K
# 5241   Female            0            0             2           Cuba  <=50K
# 4828   Female            0            0             2  United-States  <=50K
# 34198    Male            0            0             2  United-States  <=50K
# 36147    Male            0            0             2  United-States  <=50K
# 2689   Female            0            0             2  United-States  <=50K
# 22895  Female            0            0             2  United-States  <=50K
# 25728  Female            0            0             2  United-States  <=50K
# 22787    Male            0            0             2  United-States  <=50K
# 36511    Male            0            0             2  United-States  <=50K
# 44088    Male            0            0             2  United-States  <=50K
# 23586    Male            0            0             2  United-States  <=50K
# 1151   Female            0            0             2  United-States  <=50K
# 1066     Male            0            3             4  United-States   >50K
# 21880  Female            0            0             2  United-States  <=50K
# 39424  Female            0            0             2  United-States  <=50K
# 1881     Male            0            0             2  United-States   >50K
# 40415    Male            4            0             3  United-States   >50K
# 48318    Male            0            0             2           Cuba   >50K
# 4432     Male            0            0             1  United-States  <=50K
# 47826  Female            0            0             2  United-States  <=50K
# 48404  Female            0            0             3  United-States   >50K

# %%
# trying to iterate 50 samples 100 times and calculating the mean of the entire thing 
# df.iloc[samples, 'age'].mean()

sample_mean = {}
means = []
for i in range(0, 100):
    samples = random.sample(range(0, df.shape[0]), 50)
    means.append(df.iloc[samples, 0].mean())

sample_mean['100sam_with_50ele'] = means
np.mean(sample_mean['100sam_with_50ele'])
# Out:
# 1.8031999999999997

# %%
sns.distplot(np.array(sample_mean['100sam_with_50ele']))
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
# trying to iterate 100 samples 100 times and calculating the mean of the entire thing

means = []
for i in range(0, 100):
    samples = random.sample(range(0, df.shape[0]), 100)
    means.append(df.iloc[samples, 0].mean())

sample_mean['100sam_with_100ele'] = means

# %%
np.mean(sample_mean['100sam_with_100ele'])
# Out:
# 1.7622000000000002

# %%
sns.distplot(np.array(sample_mean['100sam_with_100ele']))
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
def fun(m_sample, n_element):
    means = []
    for i in range(0, m_sample):
        samples = random.sample(range(0, df.shape[0]), n_element)
        means.append(df.iloc[samples, 0].mean())
    return means

# %%
sample_mean = {}

sample_mean['100sam_with_50ele'] = fun(100, 50)
sample_mean['1000sam_with_50ele'] = fun(1000, 50)

sample_mean['100sam_with_100ele'] = fun(100, 100)
sample_mean['1000sam_with_100ele'] = fun(1000, 100)

sample_mean['100sam_with_1000ele'] = fun(100, 1000)
sample_mean['1000sam_with_1000ele'] = fun(1000, 1000)

# %%
plt.figure(figsize=(12, 6))
plt.subplots_adjust(hspace=0.4, wspace=0.7)

plt.subplot(2, 3, 1)
sns.distplot(np.array(sample_mean['100sam_with_50ele']))
plt.title('100sam_with_50ele')

plt.subplot(2, 3, 2)
sns.distplot(np.array(sample_mean['100sam_with_100ele']))
plt.title('100sam_with_100ele')

plt.subplot(2, 3, 3)
sns.distplot(np.array(sample_mean['100sam_with_1000ele']))
plt.title('100sam_with_1000ele')

plt.subplot(2, 3, 4)
sns.distplot(np.array(sample_mean['1000sam_with_50ele']))
plt.title('1000sam_with_50ele')

plt.subplot(2, 3, 5)
sns.distplot(np.array(sample_mean['1000sam_with_100ele']))
plt.title('1000sam_with_100ele')

plt.subplot(2, 3, 6)
sns.distplot(np.array(sample_mean['1000sam_with_1000ele']))
plt.title('1000sam_with_1000ele')
# Out:
# Text(0.5, 1.0, '1000sam_with_1000ele')
